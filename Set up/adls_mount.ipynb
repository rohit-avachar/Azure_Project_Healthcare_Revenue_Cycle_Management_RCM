# %%
# Storage Account Details
storage_account = "ttadlsdev2318"

# Read Storage Account Key from Databricks Secret Scope
storage_key = dbutils.secrets.get(
    scope="tt-hc-kv",
    key="tt-adls-access-key-dev"
)

# Configure Spark to access ADLS Gen2
spark.conf.set(
    f"fs.azure.account.key.{storage_account}.dfs.core.windows.net",
    storage_key
)

# %%
landing_path = f"abfss://landing@{storage_account}.dfs.core.windows.net/"
bronze_path = f"abfss://bronze@{storage_account}.dfs.core.windows.net/"
silver_path = f"abfss://silver@{storage_account}.dfs.core.windows.net/"
gold_path = f"abfss://gold@{storage_account}.dfs.core.windows.net/"
configs_path = f"abfss://configs@{storage_account}.dfs.core.windows.net/"
