# %%
# %sql
CREATE TABLE IF NOT EXISTS tt_hc_adb_ws.gold.dim_npi (
  npi_id STRING,
  first_name STRING,
  last_name STRING,
  position STRING,
  organisation_name STRING,
  last_updated STRING,
  refreshed_at TIMESTAMP)

# %%
# %sql
truncate table tt_hc_adb_ws.gold.dim_npi

# %%
# %sql
insert into
  tt_hc_adb_ws.gold.dim_npi
select
  npi_id,
  first_name,
  last_name,
  position,
  organisation_name,
  last_updated,
  current_timestamp()
from
  tt_hc_adb_ws.silver.npi_extract
  where is_current_flag = true

# %%
# %sql
select * from tt_hc_adb_ws.gold.dim_npi
